# %%
import pandas as pd


df = pd.read_csv(r"C:\Users\dkreh\Desktop\KDT_RE_5th\3_Project\01_DataAnalysis\data\policy\한국언론진흥재단_뉴스빅데이터_메타데이터_뉴딜정책_20210731.csv", encoding="cp949")


df.head()
# Out:
#                                                   주소          일자   언론사  \
# 0  http://www.bigkinds.or.kr/news/newsDetailView....  2021-07-01  서울경제
# 1  http://www.bigkinds.or.kr/news/newsDetailView....  2021-07-01  서울신문
# 2  http://www.bigkinds.or.kr/news/newsDetailView....  2021-07-01  대구일보
# 3  http://www.bigkinds.or.kr/news/newsDetailView....  2021-07-01  강원일보
# 4  http://www.bigkinds.or.kr/news/newsDetailView....  2021-07-01  매일경제
#
#       기고자                                                 제목    통합 분류1  \
# 0  박진용 기자              출사표 던진 이재명 이재명표 뉴딜 정책 실시..공정성장의 길 열겠다   정치>정치일반
# 1     이명선  재임중 인증·선정 427건 수상·2723억원 외부재원 확보… “시민·직원이 빚어낸 ...     지역>경기
# 2     김일기              에너지 자립화와 탄소중립 메카로…상주축산환경사업소 그린뉴딜정책 선도     경제>자원
# 3  김영석,기자                   저탄소 인프라 구축 '친환경 그린리조트' 거듭나는 강원랜드     지역>충남
# 4     전종헌                트럼프, '역대 최악' 대통령은 아냐…미국 역사가 평가 살펴보니  국제>미국_북미
#
#    통합 분류2  통합 분류3     사건_사고 분류1 사건_사고 분류2 사건_사고 분류3  \
# 0     NaN     NaN  범죄>기업범죄>거래제한       NaN       NaN
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dkreh\Desktop\KDT_RE_5th\3_Project\01_DataAnalysis\data\raw\energy\신·재생_에너지생산량_강원_20251215135106.csv", encoding="utf-8")


df
# Out:
#                  에너지별(1)  에너지별(2)    에너지별(3)     2022  2022.1 2022.2  2022.3  \
# 0                에너지별(1)  에너지별(2)    에너지별(3)       강원     춘천시    원주시     강릉시
# 1       신·재생에너지 합계 (toe)       소계         소계  1730425  220719  56095  479264
# 2       신·재생에너지 합계 (toe)    재생에너지         소계  1671606  220641  56019  479235
# 3       신·재생에너지 합계 (toe)     신에너지         소계    58819      77     77      29
# 4   신·재생에너지 지역별 공급비중 (%)       소계         소계   100.00   12.76   3.24   27.70
# 5            재생에너지 (toe)      태양열         소계     2492     146    209     508
# 6            재생에너지 (toe)      태양광         소계   468677   23466  39050   32666
# 7            재생에너지 (toe)      태양광        사업용   411415   16441  31410   27075
# 8            재생에너지 (toe)      태양광        자가용    57262    7024   7640    5591
# 9            재생에너지 (toe)       풍력         소계   203379       7      -   18284
# 10           재생에너지 (toe)       풍력        사업용   202876       -      -   18279
# ...
